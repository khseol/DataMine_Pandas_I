# %%
def getRedFreq(rgb, red):

  #for loop for the red component
    for i in range(len(rgb)):
        if rgb[i][0] in red.keys():
            red[(rgb[i][0])] +=1
        else:
            red.update({rgb[i][0] : 1})

    return red

# %%
def getGreenFreq(rgb, green):

  #for loop for the green component    
    for i in range(len(rgb)):
        if rgb[i][1] in green.keys():
            green[(rgb[i][1])] +=1
        else:
            green.update({rgb[i][1] : 1})
  

    return green

# %%
def getBlueFreq(rgb, blue):

    #for loop for the blue component
    for i in range(len(rgb)):
        if rgb[i][2] in blue.keys():
            blue[(rgb[i][2])] +=1
        else:
            blue.update({rgb[i][2] : 1})
            
    return blue

# %%
#Function for normalizing the frequencies
#This is the last part to do and then output the graph!!!
def normalize(component,normal_component):
    #To normalize a component...
    #frequency / total number of pixels ie. dimensions (256*256 and 512*512)
    for keys in component.keys():
        print('this is the current key: ' + str(keys))
        print('This is the current key vlaue: ' + str(component[keys]))
        normal = (component[keys] / (512*512)) #TOTAL NUMBER OF PIXELS CHANGES DEPENDING ON THE SIZE AND FILE BEING READ
        normal_component.update({keys:normal})
        print('current keys normalized value: ' + str(normal))
        
    return normal_component

# %%
string_pixel = ''
pixel = []

#THIS VALUE CHANGES DEPENDING ON THE FILE BEING READ
with open ('kseol_hard.txt') as op:
    for i in op.readlines():
        string_pixel = i
        pixel.append(string_pixel.split())

#for-loop below changes the string number into int numbers
for i in range(len(pixel)):
    for j in range(len(pixel[i])):
        pixel[i][j] = int(pixel[i][j])

        
red_component = {}
green_component = {}
blue_component = {}

print('This is the red component\n')
red = getRedFreq(pixel,red_component)
normalize_r = {}
red_normal = normalize(red,normalize_r)

print('\nThis is the green component')
#print('this is for the green component')
green = getGreenFreq(pixel, green_component)
normalize_g = {}
green_normal = normalize(green,normalize_g)

print('\nThis is the blue component\n')
#print('this is for the blue component')
blue = getBlueFreq(pixel, blue_component)
normalize_b = {}
blue_normal = normalize(blue,normalize_b)


#these values and functions change depending on which component is being analyzed
# Out:
# This is the red component
#
# this is the current key: 201
# This is the current key vlaue: 1025
# current keys normalized value: 0.003910064697265625
# this is the current key: 189
# This is the current key vlaue: 1337
# current keys normalized value: 0.005100250244140625
# this is the current key: 180
# This is the current key vlaue: 1312
# current keys normalized value: 0.0050048828125
# this is the current key: 172
# This is the current key vlaue: 1006
# current keys normalized value: 0.00383758544921875
# this is the current key: 163
# This is the current key vlaue: 1363
# current keys normalized value: 0.005199432373046875
# this is the current key: 152
# This is the current key vlaue: 1821
# current keys normalized value: 0.006946563720703125
# this is the current key: 146
# This is the current key vlaue: 2110
# current keys normalized value: 0.00804901123046875
# this is the current key: 136
# This is the current key vlaue: 1416
# current keys normalized value: 0.005401611328125
# this is the current key: 113
# This is the current key vlaue: 440
# current keys normalized value: 0.001678466796875
# this is the current key: 102
# This is the current key vlaue: 417
# current keys normalized value: 0.001590728759765625
# this is the current key: 107
# This is the current key vlaue: 407
# current keys normalized value: 0.001552581787109375
# this is the current key: 139
# This is the current key vlaue: 1444
# current keys normalized value: 0.0055084228515625
# this is the current key: 165
# This is the current key vlaue: 1288
# current keys normalized value: 0.004913330078125
# this is the current key: 177
# This is the current key vlaue: 1187
# current keys normalized value: 0.004528045654296875
# this is the current key: 182
# This is the current key vlaue: 1238
# current keys normalized value: 0.00472259521484375
# this is the current key: 151
# This is the current key vlaue: 1897
# current keys normalized value: 0.007236480712890625
# this is the current key: 137
# This is the current key vlaue: 1447
# current keys normalized value: 0.005519866943359375
# this is the current key: 130
# This is the current key vlaue: 758
# current keys normalized value: 0.00289154052734375
# this is the current key: 121
# This is the current key vlaue: 544
# current keys normalized value: 0.0020751953125
# this is the current key: 108
# This is the current key vlaue: 403
# current keys normalized value: 0.001537322998046875
# this is the current key: 97
# This is the current key vlaue: 477
# current keys normalized value: 0.001819610595703125
# this is the current key: 85
# This is the current key vlaue: 398
# current keys normalized value: 0.00151824951171875
# this is the current key: 77
# This is the current key vlaue: 559
# current keys normalized value: 0.002132415771484375
# this is the current key: 73
# This is the current key vlaue: 575
# current keys normalized value: 0.002193450927734375
# this is the current key: 109
# This is the current key vlaue: 455
# current keys normalized value: 0.001735687255859375
# this is the current key: 155
# This is the current key vlaue: 1827
# current keys normalized value: 0.006969451904296875
# this is the current key: 179
# This is the current key vlaue: 1284
# current keys normalized value: 0.0048980712890625
# this is the current key: 190
# This is the current key vlaue: 1396
# current keys normalized value: 0.0053253173828125
# this is the current key: 185
# This is the current key vlaue: 1248
# current keys normalized value: 0.0047607421875
# this is the current key: 175
# This is the current key vlaue: 1131
# current keys normalized value: 0.004314422607421875
# this is the current key: 153
# This is the current key vlaue: 1819
# current keys normalized value: 0.006938934326171875
# this is the current key: 125
# This is the current key vlaue: 625
# current keys normalized value: 0.002384185791015625
# this is the current key: 111
# This is the current key vlaue: 486
# current keys normalized value: 0.00185394287109375
# this is the current key: 101
# This is the current key vlaue: 431
# current keys normalized value: 0.001644134521484375
# this is the current key: 100
# This is the current key vlaue: 428
# current keys normalized value: 0.0016326904296875
# this is the current key: 103
# This is the current key vlaue: 420
# current keys normalized value: 0.0016021728515625
# this is the current key: 138
# This is the current key vlaue: 1446
# current keys normalized value: 0.00551605224609375
# this is the current key: 170
# This is the current key vlaue: 1121
# current keys normalized value: 0.004276275634765625
# this is the current key: 203
# This is the current key vlaue: 1053
# current keys normalized value: 0.004016876220703125
# this is the current key: 205
# This is the current key vlaue: 1154
# current keys normalized value: 0.00440216064453125
# this is the current key: 204
# This is the current key vlaue: 1152
# current keys normalized value: 0.00439453125
# this is the current key: 206
# This is the current key vlaue: 1334
# current keys normalized value: 0.00508880615234375
# this is the current key: 207
# This is the current key vlaue: 1361
# current keys normalized value: 0.005191802978515625
# this is the current key: 200
# This is the current key vlaue: 1049
# current keys normalized value: 0.004001617431640625
# this is the current key: 196
# This is the current key vlaue: 1061
# current keys normalized value: 0.004047393798828125
# this is the current key: 192
# This is the current key vlaue: 1238
# current keys normalized value: 0.00472259521484375
# this is the current key: 186
# This is the current key vlaue: 1297
# current keys normalized value: 0.004947662353515625
# this is the current key: 194
# This is the current key vlaue: 1165
# current keys normalized value: 0.004444122314453125
# this is the current key: 197
# This is the current key vlaue: 1022
# current keys normalized value: 0.00389862060546875
# this is the current key: 202
# This is the current key vlaue: 1048
# current keys normalized value: 0.003997802734375
# this is the current key: 209
# This is the current key vlaue: 1389
# current keys normalized value: 0.005298614501953125
# this is the current key: 217
# This is the current key vlaue: 1641
# current keys normalized value: 0.006259918212890625
# this is the current key: 229
# This is the current key vlaue: 5194
# current keys normalized value: 0.01981353759765625
# this is the current key: 238
# This is the current key vlaue: 1148
# current keys normalized value: 0.0043792724609375
# this is the current key: 243
# This is the current key vlaue: 432
# current keys normalized value: 0.00164794921875
# this is the current key: 247
# This is the current key vlaue: 359
# current keys normalized value: 0.001369476318359375
# this is the current key: 246
# This is the current key vlaue: 341
# current keys normalized value: 0.001300811767578125
# this is the current key: 244
# This is the current key vlaue: 386
# current keys normalized value: 0.00147247314453125
# this is the current key: 240
# This is the current key vlaue: 790
# current keys normalized value: 0.00301361083984375
# this is the current key: 232
# This is the current key vlaue: 4337
# current keys normalized value: 0.016544342041015625
# this is the current key: 224
# This is the current key vlaue: 3474
# current keys normalized value: 0.01325225830078125
# this is the current key: 214
# This is the current key vlaue: 1910
# current keys normalized value: 0.00728607177734375
# this is the current key: 187
# This is the current key vlaue: 1364
# current keys normalized value: 0.0052032470703125
# this is the current key: 174
# This is the current key vlaue: 1095
# current keys normalized value: 0.004177093505859375
# this is the current key: 160
# This is the current key vlaue: 1608
# current keys normalized value: 0.006134033203125
# this is the current key: 141
# This is the current key vlaue: 1719
# current keys normalized value: 0.006557464599609375
# this is the current key: 134
# This is the current key vlaue: 1167
# current keys normalized value: 0.004451751708984375
# this is the current key: 127
# This is the current key vlaue: 660
# current keys normalized value: 0.0025177001953125
# this is the current key: 128
# This is the current key vlaue: 688
# current keys normalized value: 0.00262451171875
# this is the current key: 126
# This is the current key vlaue: 623
# current keys normalized value: 0.002376556396484375
# this is the current key: 118
# This is the current key vlaue: 510
# current keys normalized value: 0.00194549560546875
# this is the current key: 89
# This is the current key vlaue: 394
# current keys normalized value: 0.00150299072265625
# this is the current key: 80
# This is the current key vlaue: 537
# current keys normalized value: 0.002048492431640625
# this is the current key: 66
# This is the current key vlaue: 451
# current keys normalized value: 0.001720428466796875
# this is the current key: 53
# This is the current key vlaue: 726
# current keys normalized value: 0.00276947021484375
# this is the current key: 49
# This is the current key vlaue: 695
# current keys normalized value: 0.002651214599609375
# this is the current key: 52
# This is the current key vlaue: 695
# current keys normalized value: 0.002651214599609375
# this is the current key: 62
# This is the current key vlaue: 532
# current keys normalized value: 0.0020294189453125
# this is the current key: 74
# This is the current key vlaue: 561
# current keys normalized value: 0.002140045166015625
# this is the current key: 82
# This is the current key vlaue: 435
# current keys normalized value: 0.001659393310546875
# this is the current key: 92
# This is the current key vlaue: 414
# current keys normalized value: 0.00157928466796875
# this is the current key: 114
# This is the current key vlaue: 487
# current keys normalized value: 0.001857757568359375
# this is the current key: 115
# This is the current key vlaue: 490
# current keys normalized value: 0.00186920166015625
# this is the current key: 116
# This is the current key vlaue: 496
# current keys normalized value: 0.00189208984375
# this is the current key: 120
# This is the current key vlaue: 558
# current keys normalized value: 0.00212860107421875
# this is the current key: 122
# This is the current key vlaue: 557
# current keys normalized value: 0.002124786376953125
# this is the current key: 124
# This is the current key vlaue: 609
# current keys normalized value: 0.002323150634765625
# this is the current key: 129
# This is the current key vlaue: 688
# current keys normalized value: 0.00262451171875
# this is the current key: 132
# This is the current key vlaue: 900
# current keys normalized value: 0.0034332275390625
# this is the current key: 133
# This is the current key vlaue: 964
# current keys normalized value: 0.0036773681640625
# this is the current key: 135
# This is the current key vlaue: 1282
# current keys normalized value: 0.00489044189453125
# this is the current key: 145
# This is the current key vlaue: 2178
# current keys normalized value: 0.00830841064453125
# this is the current key: 159
# This is the current key vlaue: 1646
# current keys normalized value: 0.00627899169921875
# this is the current key: 181
# This is the current key vlaue: 1343
# current keys normalized value: 0.005123138427734375
# this is the current key: 208
# This is the current key vlaue: 1369
# current keys normalized value: 0.005222320556640625
# this is the current key: 210
# This is the current key vlaue: 1691
# current keys normalized value: 0.006450653076171875
# this is the current key: 211
# This is the current key vlaue: 1727
# current keys normalized value: 0.006587982177734375
# this is the current key: 212
# This is the current key vlaue: 1593
# current keys normalized value: 0.006076812744140625
# this is the current key: 199
# This is the current key vlaue: 1063
# current keys normalized value: 0.004055023193359375
# this is the current key: 195
# This is the current key vlaue: 1026
# current keys normalized value: 0.00391387939453125
# this is the current key: 191
# This is the current key vlaue: 1336
# current keys normalized value: 0.005096435546875
# this is the current key: 188
# This is the current key vlaue: 1350
# current keys normalized value: 0.00514984130859375
# this is the current key: 183
# This is the current key vlaue: 1275
# current keys normalized value: 0.004863739013671875
# this is the current key: 173
# This is the current key vlaue: 1052
# current keys normalized value: 0.0040130615234375
# this is the current key: 166
# This is the current key vlaue: 1201
# current keys normalized value: 0.004581451416015625
# this is the current key: 156
# This is the current key vlaue: 1758
# current keys normalized value: 0.00670623779296875
# this is the current key: 142
# This is the current key vlaue: 1896
# current keys normalized value: 0.007232666015625
# this is the current key: 140
# This is the current key vlaue: 1593
# current keys normalized value: 0.006076812744140625
# this is the current key: 106
# This is the current key vlaue: 412
# current keys normalized value: 0.0015716552734375
# this is the current key: 94
# This is the current key vlaue: 424
# current keys normalized value: 0.001617431640625
# this is the current key: 87
# This is the current key vlaue: 370
# current keys normalized value: 0.00141143798828125
# this is the current key: 91
# This is the current key vlaue: 392
# current keys normalized value: 0.001495361328125
# this is the current key: 119
# This is the current key vlaue: 511
# current keys normalized value: 0.001949310302734375
# this is the current key: 131
# This is the current key vlaue: 825
# current keys normalized value: 0.003147125244140625
# this is the current key: 105
# This is the current key vlaue: 424
# current keys normalized value: 0.001617431640625
# this is the current key: 110
# This is the current key vlaue: 440
# current keys normalized value: 0.001678466796875
# this is the current key: 117
# This is the current key vlaue: 518
# current keys normalized value: 0.00197601318359375
# this is the current key: 112
# This is the current key vlaue: 410
# current keys normalized value: 0.00156402587890625
# this is the current key: 96
# This is the current key vlaue: 476
# current keys normalized value: 0.0018157958984375
# this is the current key: 123
# This is the current key vlaue: 629
# current keys normalized value: 0.002399444580078125
# this is the current key: 143
# This is the current key vlaue: 1974
# current keys normalized value: 0.00753021240234375
# this is the current key: 149
# This is the current key vlaue: 2096
# current keys normalized value: 0.00799560546875
# this is the current key: 154
# This is the current key vlaue: 1784
# current keys normalized value: 0.006805419921875
# this is the current key: 157
# This is the current key vlaue: 1774
# current keys normalized value: 0.00676727294921875
# this is the current key: 162
# This is the current key vlaue: 1365
# current keys normalized value: 0.005207061767578125
# this is the current key: 167
# This is the current key vlaue: 1218
# current keys normalized value: 0.00464630126953125
# this is the current key: 176
# This is the current key vlaue: 1149
# current keys normalized value: 0.004383087158203125
# this is the current key: 184
# This is the current key vlaue: 1215
# current keys normalized value: 0.004634857177734375
# this is the current key: 178
# This is the current key vlaue: 1203
# current keys normalized value: 0.004589080810546875
# this is the current key: 169
# This is the current key vlaue: 1102
# current keys normalized value: 0.00420379638671875
# this is the current key: 168
# This is the current key vlaue: 1233
# current keys normalized value: 0.004703521728515625
# this is the current key: 161
# This is the current key vlaue: 1513
# current keys normalized value: 0.005771636962890625
# this is the current key: 144
# This is the current key vlaue: 2121
# current keys normalized value: 0.008090972900390625
# this is the current key: 164
# This is the current key vlaue: 1284
# current keys normalized value: 0.0048980712890625
# this is the current key: 147
# This is the current key vlaue: 2163
# current keys normalized value: 0.008251190185546875
# this is the current key: 44
# This is the current key vlaue: 485
# current keys normalized value: 0.001850128173828125
# this is the current key: 30
# This is the current key vlaue: 518
# current keys normalized value: 0.00197601318359375
# this is the current key: 26
# This is the current key vlaue: 549
# current keys normalized value: 0.002094268798828125
# this is the current key: 22
# This is the current key vlaue: 428
# current keys normalized value: 0.0016326904296875
# this is the current key: 23
# This is the current key vlaue: 446
# current keys normalized value: 0.00170135498046875
# this is the current key: 25
# This is the current key vlaue: 592
# current keys normalized value: 0.00225830078125
# this is the current key: 19
# This is the current key vlaue: 408
# current keys normalized value: 0.001556396484375
# this is the current key: 16
# This is the current key vlaue: 352
# current keys normalized value: 0.0013427734375
# this is the current key: 14
# This is the current key vlaue: 263
# current keys normalized value: 0.001003265380859375
# this is the current key: 29
# This is the current key vlaue: 594
# current keys normalized value: 0.00226593017578125
# this is the current key: 37
# This is the current key vlaue: 463
# current keys normalized value: 0.001766204833984375
# this is the current key: 46
# This is the current key vlaue: 528
# current keys normalized value: 0.00201416015625
# this is the current key: 27
# This is the current key vlaue: 577
# current keys normalized value: 0.002201080322265625
# this is the current key: 20
# This is the current key vlaue: 424
# current keys normalized value: 0.001617431640625
# this is the current key: 48
# This is the current key vlaue: 646
# current keys normalized value: 0.00246429443359375
# this is the current key: 70
# This is the current key vlaue: 552
# current keys normalized value: 0.002105712890625
# this is the current key: 54
# This is the current key vlaue: 699
# current keys normalized value: 0.002666473388671875
# this is the current key: 65
# This is the current key vlaue: 513
# current keys normalized value: 0.001956939697265625
# this is the current key: 63
# This is the current key vlaue: 540
# current keys normalized value: 0.0020599365234375
# this is the current key: 47
# This is the current key vlaue: 638
# current keys normalized value: 0.00243377685546875
# this is the current key: 50
# This is the current key vlaue: 680
# current keys normalized value: 0.002593994140625
# this is the current key: 45
# This is the current key vlaue: 489
# current keys normalized value: 0.001865386962890625
# this is the current key: 38
# This is the current key vlaue: 411
# current keys normalized value: 0.001567840576171875
# this is the current key: 34
# This is the current key vlaue: 489
# current keys normalized value: 0.001865386962890625
# this is the current key: 18
# This is the current key vlaue: 385
# current keys normalized value: 0.001468658447265625
# this is the current key: 17
# This is the current key vlaue: 424
# current keys normalized value: 0.001617431640625
# this is the current key: 33
# This is the current key vlaue: 485
# current keys normalized value: 0.001850128173828125
# this is the current key: 239
# This is the current key vlaue: 891
# current keys normalized value: 0.003398895263671875
# this is the current key: 255
# This is the current key vlaue: 1798
# current keys normalized value: 0.00685882568359375
# this is the current key: 253
# This is the current key vlaue: 531
# current keys normalized value: 0.002025604248046875
# this is the current key: 225
# This is the current key vlaue: 4044
# current keys normalized value: 0.0154266357421875
# this is the current key: 193
# This is the current key vlaue: 1258
# current keys normalized value: 0.00479888916015625
# this is the current key: 95
# This is the current key vlaue: 441
# current keys normalized value: 0.001682281494140625
# this is the current key: 76
# This is the current key vlaue: 529
# current keys normalized value: 0.002017974853515625
# this is the current key: 198
# This is the current key vlaue: 1024
# current keys normalized value: 0.00390625
# this is the current key: 223
# This is the current key vlaue: 3128
# current keys normalized value: 0.011932373046875
# this is the current key: 233
# This is the current key vlaue: 3337
# current keys normalized value: 0.012729644775390625
# this is the current key: 242
# This is the current key vlaue: 520
# current keys normalized value: 0.001983642578125
# this is the current key: 237
# This is the current key vlaue: 1385
# current keys normalized value: 0.005283355712890625
# this is the current key: 230
# This is the current key vlaue: 5242
# current keys normalized value: 0.01999664306640625
# this is the current key: 220
# This is the current key vlaue: 2034
# current keys normalized value: 0.00775909423828125
# this is the current key: 67
# This is the current key vlaue: 502
# current keys normalized value: 0.00191497802734375
# this is the current key: 51
# This is the current key vlaue: 651
# current keys normalized value: 0.002483367919921875
# this is the current key: 58
# This is the current key vlaue: 699
# current keys normalized value: 0.002666473388671875
# this is the current key: 148
# This is the current key vlaue: 2127
# current keys normalized value: 0.008113861083984375
# this is the current key: 98
# This is the current key vlaue: 481
# current keys normalized value: 0.001834869384765625
# this is the current key: 86
# This is the current key vlaue: 376
# current keys normalized value: 0.001434326171875
# this is the current key: 90
# This is the current key vlaue: 420
# current keys normalized value: 0.0016021728515625
# this is the current key: 104
# This is the current key vlaue: 453
# current keys normalized value: 0.001728057861328125
# this is the current key: 99
# This is the current key vlaue: 504
# current keys normalized value: 0.001922607421875
# this is the current key: 171
# This is the current key vlaue: 1069
# current keys normalized value: 0.004077911376953125
# this is the current key: 78
# This is the current key vlaue: 595
# current keys normalized value: 0.002269744873046875
# this is the current key: 28
# This is the current key vlaue: 589
# current keys normalized value: 0.002246856689453125
# this is the current key: 24
# This is the current key vlaue: 529
# current keys normalized value: 0.002017974853515625
# this is the current key: 21
# This is the current key vlaue: 442
# current keys normalized value: 0.00168609619140625
# this is the current key: 41
# This is the current key vlaue: 378
# current keys normalized value: 0.00144195556640625
# this is the current key: 40
# This is the current key vlaue: 409
# current keys normalized value: 0.001560211181640625
# this is the current key: 36
# This is the current key vlaue: 439
# current keys normalized value: 0.001674652099609375
# this is the current key: 61
# This is the current key vlaue: 518
# current keys normalized value: 0.00197601318359375
# this is the current key: 72
# This is the current key vlaue: 541
# current keys normalized value: 0.002063751220703125
# this is the current key: 57
# This is the current key vlaue: 722
# current keys normalized value: 0.00275421142578125
# this is the current key: 55
# This is the current key vlaue: 712
# current keys normalized value: 0.002716064453125
# this is the current key: 43
# This is the current key vlaue: 420
# current keys normalized value: 0.0016021728515625
# this is the current key: 31
# This is the current key vlaue: 486
# current keys normalized value: 0.00185394287109375
# this is the current key: 250
# This is the current key vlaue: 524
# current keys normalized value: 0.0019989013671875
# this is the current key: 251
# This is the current key vlaue: 539
# current keys normalized value: 0.002056121826171875
# this is the current key: 158
# This is the current key vlaue: 1689
# current keys normalized value: 0.006443023681640625
# this is the current key: 69
# This is the current key vlaue: 522
# current keys normalized value: 0.00199127197265625
# this is the current key: 215
# This is the current key vlaue: 1740
# current keys normalized value: 0.0066375732421875
# this is the current key: 241
# This is the current key vlaue: 584
# current keys normalized value: 0.002227783203125
# this is the current key: 234
# This is the current key vlaue: 2742
# current keys normalized value: 0.01045989990234375
# this is the current key: 226
# This is the current key vlaue: 4553
# current keys normalized value: 0.017368316650390625
# this is the current key: 88
# This is the current key vlaue: 419
# current keys normalized value: 0.001598358154296875
# this is the current key: 75
# This is the current key vlaue: 564
# current keys normalized value: 0.0021514892578125
# this is the current key: 56
# This is the current key vlaue: 690
# current keys normalized value: 0.00263214111328125
# this is the current key: 71
# This is the current key vlaue: 579
# current keys normalized value: 0.002208709716796875
# this is the current key: 83
# This is the current key vlaue: 402
# current keys normalized value: 0.00153350830078125
# this is the current key: 15
# This is the current key vlaue: 368
# current keys normalized value: 0.00140380859375
# this is the current key: 35
# This is the current key vlaue: 434
# current keys normalized value: 0.00165557861328125
# this is the current key: 60
# This is the current key vlaue: 594
# current keys normalized value: 0.00226593017578125
# this is the current key: 64
# This is the current key vlaue: 523
# current keys normalized value: 0.001995086669921875
# this is the current key: 84
# This is the current key vlaue: 404
# current keys normalized value: 0.0015411376953125
# this is the current key: 39
# This is the current key vlaue: 388
# current keys normalized value: 0.0014801025390625
# this is the current key: 42
# This is the current key vlaue: 417
# current keys normalized value: 0.001590728759765625
# this is the current key: 68
# This is the current key vlaue: 466
# current keys normalized value: 0.00177764892578125
# this is the current key: 248
# This is the current key vlaue: 395
# current keys normalized value: 0.001506805419921875
# this is the current key: 81
# This is the current key vlaue: 468
# current keys normalized value: 0.0017852783203125
# this is the current key: 213
# This is the current key vlaue: 1763
# current keys normalized value: 0.006725311279296875
# this is the current key: 221
# This is the current key vlaue: 2384
# current keys normalized value: 0.00909423828125
# this is the current key: 231
# This is the current key vlaue: 4811
# current keys normalized value: 0.018352508544921875
# this is the current key: 236
# This is the current key vlaue: 1826
# current keys normalized value: 0.00696563720703125
# this is the current key: 150
# This is the current key vlaue: 1914
# current keys normalized value: 0.00730133056640625
# this is the current key: 79
# This is the current key vlaue: 563
# current keys normalized value: 0.002147674560546875
# this is the current key: 13
# This is the current key vlaue: 255
# current keys normalized value: 0.000972747802734375
# this is the current key: 59
# This is the current key vlaue: 669
# current keys normalized value: 0.002552032470703125
# this is the current key: 228
# This is the current key vlaue: 5104
# current keys normalized value: 0.01947021484375
# this is the current key: 222
# This is the current key vlaue: 2641
# current keys normalized value: 0.010074615478515625
# this is the current key: 93
# This is the current key vlaue: 409
# current keys normalized value: 0.001560211181640625
# this is the current key: 12
# This is the current key vlaue: 250
# current keys normalized value: 0.00095367431640625
# this is the current key: 32
# This is the current key vlaue: 491
# current keys normalized value: 0.001873016357421875
# this is the current key: 216
# This is the current key vlaue: 1617
# current keys normalized value: 0.006168365478515625
# this is the current key: 227
# This is the current key vlaue: 4892
# current keys normalized value: 0.0186614990234375
# this is the current key: 219
# This is the current key vlaue: 1842
# current keys normalized value: 0.00702667236328125
# this is the current key: 218
# This is the current key vlaue: 1689
# current keys normalized value: 0.006443023681640625
# this is the current key: 235
# This is the current key vlaue: 2210
# current keys normalized value: 0.00843048095703125
# this is the current key: 11
# This is the current key vlaue: 209
# current keys normalized value: 0.000797271728515625
# this is the current key: 249
# This is the current key vlaue: 451
# current keys normalized value: 0.001720428466796875
# this is the current key: 10
# This is the current key vlaue: 160
# current keys normalized value: 0.0006103515625
# this is the current key: 254
# This is the current key vlaue: 770
# current keys normalized value: 0.00293731689453125
# this is the current key: 245
# This is the current key vlaue: 334
# current keys normalized value: 0.00127410888671875
# this is the current key: 8
# This is the current key vlaue: 55
# current keys normalized value: 0.000209808349609375
# this is the current key: 9
# This is the current key vlaue: 94
# current keys normalized value: 0.00035858154296875
# this is the current key: 252
# This is the current key vlaue: 440
# current keys normalized value: 0.001678466796875
# this is the current key: 7
# This is the current key vlaue: 35
# current keys normalized value: 0.000133514404296875
# this is the current key: 4
# This is the current key vlaue: 19
# current keys normalized value: 7.2479248046875e-05
# this is the current key: 5
# This is the current key vlaue: 14
# current keys normalized value: 5.340576171875e-05
# this is the current key: 0
# This is the current key vlaue: 11
# current keys normalized value: 4.1961669921875e-05
# this is the current key: 6
# This is the current key vlaue: 28
# current keys normalized value: 0.0001068115234375
# this is the current key: 3
# This is the current key vlaue: 14
# current keys normalized value: 5.340576171875e-05
# this is the current key: 1
# This is the current key vlaue: 17
# current keys normalized value: 6.4849853515625e-05
# this is the current key: 2
# This is the current key vlaue: 9
# current keys normalized value: 3.4332275390625e-05
#
# This is the green component
# this is the current key: 27
# This is the current key vlaue: 809
# current keys normalized value: 0.003086090087890625
# this is the current key: 22
# This is the current key vlaue: 497
# current keys normalized value: 0.001895904541015625
# this is the current key: 26
# This is the current key vlaue: 818
# current keys normalized value: 0.00312042236328125
# this is the current key: 32
# This is the current key vlaue: 453
# current keys normalized value: 0.001728057861328125
# this is the current key: 38
# This is the current key vlaue: 455
# current keys normalized value: 0.001735687255859375
# this is the current key: 43
# This is the current key vlaue: 311
# current keys normalized value: 0.001186370849609375
# this is the current key: 51
# This is the current key vlaue: 435
# current keys normalized value: 0.001659393310546875
# this is the current key: 71
# This is the current key vlaue: 777
# current keys normalized value: 0.002964019775390625
# this is the current key: 92
# This is the current key vlaue: 1538
# current keys normalized value: 0.00586700439453125
# this is the current key: 109
# This is the current key vlaue: 1629
# current keys normalized value: 0.006214141845703125
# this is the current key: 130
# This is the current key vlaue: 830
# current keys normalized value: 0.00316619873046875
# this is the current key: 161
# This is the current key vlaue: 939
# current keys normalized value: 0.003582000732421875
# this is the current key: 174
# This is the current key vlaue: 1559
# current keys normalized value: 0.005947113037109375
# this is the current key: 180
# This is the current key vlaue: 2213
# current keys normalized value: 0.008441925048828125
# this is the current key: 190
# This is the current key vlaue: 3685
# current keys normalized value: 0.014057159423828125
# this is the current key: 194
# This is the current key vlaue: 3026
# current keys normalized value: 0.01154327392578125
# this is the current key: 197
# This is the current key vlaue: 2509
# current keys normalized value: 0.009571075439453125
# this is the current key: 200
# This is the current key vlaue: 2260
# current keys normalized value: 0.0086212158203125
# this is the current key: 201
# This is the current key vlaue: 2202
# current keys normalized value: 0.00839996337890625
# this is the current key: 198
# This is the current key vlaue: 2405
# current keys normalized value: 0.009174346923828125
# this is the current key: 191
# This is the current key vlaue: 3640
# current keys normalized value: 0.013885498046875
# this is the current key: 184
# This is the current key vlaue: 3085
# current keys normalized value: 0.011768341064453125
# this is the current key: 178
# This is the current key vlaue: 2019
# current keys normalized value: 0.007701873779296875
# this is the current key: 170
# This is the current key vlaue: 1301
# current keys normalized value: 0.004962921142578125
# this is the current key: 160
# This is the current key vlaue: 995
# current keys normalized value: 0.003795623779296875
# this is the current key: 208
# This is the current key vlaue: 1451
# current keys normalized value: 0.005535125732421875
# this is the current key: 213
# This is the current key vlaue: 1320
# current keys normalized value: 0.005035400390625
# this is the current key: 212
# This is the current key vlaue: 1355
# current keys normalized value: 0.005168914794921875
# this is the current key: 207
# This is the current key vlaue: 1796
# current keys normalized value: 0.0068511962890625
# this is the current key: 187
# This is the current key vlaue: 3667
# current keys normalized value: 0.013988494873046875
# this is the current key: 175
# This is the current key vlaue: 1601
# current keys normalized value: 0.006107330322265625
# this is the current key: 158
# This is the current key vlaue: 915
# current keys normalized value: 0.003490447998046875
# this is the current key: 146
# This is the current key vlaue: 826
# current keys normalized value: 0.00315093994140625
# this is the current key: 129
# This is the current key vlaue: 845
# current keys normalized value: 0.003223419189453125
# this is the current key: 119
# This is the current key vlaue: 875
# current keys normalized value: 0.003337860107421875
# this is the current key: 117
# This is the current key vlaue: 1002
# current keys normalized value: 0.00382232666015625
# this is the current key: 118
# This is the current key vlaue: 928
# current keys normalized value: 0.0035400390625
# this is the current key: 147
# This is the current key vlaue: 866
# current keys normalized value: 0.00330352783203125
# this is the current key: 173
# This is the current key vlaue: 1415
# current keys normalized value: 0.005397796630859375
# this is the current key: 199
# This is the current key vlaue: 2341
# current keys normalized value: 0.008930206298828125
# this is the current key: 192
# This is the current key vlaue: 3487
# current keys normalized value: 0.013301849365234375
# this is the current key: 186
# This is the current key vlaue: 3408
# current keys normalized value: 0.01300048828125
# this is the current key: 179
# This is the current key vlaue: 2142
# current keys normalized value: 0.00817108154296875
# this is the current key: 171
# This is the current key vlaue: 1295
# current keys normalized value: 0.004940032958984375
# this is the current key: 169
# This is the current key vlaue: 1181
# current keys normalized value: 0.004505157470703125
# this is the current key: 181
# This is the current key vlaue: 2522
# current keys normalized value: 0.00962066650390625
# this is the current key: 188
# This is the current key vlaue: 3690
# current keys normalized value: 0.01407623291015625
# this is the current key: 196
# This is the current key vlaue: 2668
# current keys normalized value: 0.0101776123046875
# this is the current key: 218
# This is the current key vlaue: 892
# current keys normalized value: 0.0034027099609375
# this is the current key: 227
# This is the current key vlaue: 1016
# current keys normalized value: 0.003875732421875
# this is the current key: 231
# This is the current key vlaue: 637
# current keys normalized value: 0.002429962158203125
# this is the current key: 235
# This is the current key vlaue: 460
# current keys normalized value: 0.0017547607421875
# this is the current key: 234
# This is the current key vlaue: 526
# current keys normalized value: 0.00200653076171875
# this is the current key: 232
# This is the current key vlaue: 613
# current keys normalized value: 0.002338409423828125
# this is the current key: 228
# This is the current key vlaue: 1034
# current keys normalized value: 0.00394439697265625
# this is the current key: 221
# This is the current key vlaue: 838
# current keys normalized value: 0.00319671630859375
# this is the current key: 211
# This is the current key vlaue: 1300
# current keys normalized value: 0.0049591064453125
# this is the current key: 156
# This is the current key vlaue: 854
# current keys normalized value: 0.00325775146484375
# this is the current key: 140
# This is the current key vlaue: 732
# current keys normalized value: 0.0027923583984375
# this is the current key: 132
# This is the current key vlaue: 885
# current keys normalized value: 0.003376007080078125
# this is the current key: 126
# This is the current key vlaue: 761
# current keys normalized value: 0.002902984619140625
# this is the current key: 121
# This is the current key vlaue: 769
# current keys normalized value: 0.002933502197265625
# this is the current key: 115
# This is the current key vlaue: 1154
# current keys normalized value: 0.00440216064453125
# this is the current key: 110
# This is the current key vlaue: 1508
# current keys normalized value: 0.0057525634765625
# this is the current key: 108
# This is the current key vlaue: 1727
# current keys normalized value: 0.006587982177734375
# this is the current key: 107
# This is the current key vlaue: 1791
# current keys normalized value: 0.006832122802734375
# this is the current key: 104
# This is the current key vlaue: 1640
# current keys normalized value: 0.006256103515625
# this is the current key: 102
# This is the current key vlaue: 1571
# current keys normalized value: 0.005992889404296875
# this is the current key: 100
# This is the current key vlaue: 1625
# current keys normalized value: 0.006198883056640625
# this is the current key: 96
# This is the current key vlaue: 1622
# current keys normalized value: 0.00618743896484375
# this is the current key: 93
# This is the current key vlaue: 1468
# current keys normalized value: 0.0055999755859375
# this is the current key: 88
# This is the current key vlaue: 1138
# current keys normalized value: 0.00434112548828125
# this is the current key: 77
# This is the current key vlaue: 774
# current keys normalized value: 0.00295257568359375
# this is the current key: 68
# This is the current key vlaue: 712
# current keys normalized value: 0.002716064453125
# this is the current key: 60
# This is the current key vlaue: 517
# current keys normalized value: 0.001972198486328125
# this is the current key: 48
# This is the current key vlaue: 473
# current keys normalized value: 0.001804351806640625
# this is the current key: 36
# This is the current key vlaue: 428
# current keys normalized value: 0.0016326904296875
# this is the current key: 37
# This is the current key vlaue: 485
# current keys normalized value: 0.001850128173828125
# this is the current key: 46
# This is the current key vlaue: 406
# current keys normalized value: 0.00154876708984375
# this is the current key: 57
# This is the current key vlaue: 560
# current keys normalized value: 0.00213623046875
# this is the current key: 63
# This is the current key vlaue: 577
# current keys normalized value: 0.002201080322265625
# this is the current key: 69
# This is the current key vlaue: 697
# current keys normalized value: 0.002658843994140625
# this is the current key: 75
# This is the current key vlaue: 768
# current keys normalized value: 0.0029296875
# this is the current key: 80
# This is the current key vlaue: 858
# current keys normalized value: 0.00327301025390625
# this is the current key: 81
# This is the current key vlaue: 948
# current keys normalized value: 0.0036163330078125
# this is the current key: 83
# This is the current key vlaue: 1000
# current keys normalized value: 0.003814697265625
# this is the current key: 82
# This is the current key vlaue: 927
# current keys normalized value: 0.003536224365234375
# this is the current key: 84
# This is the current key vlaue: 916
# current keys normalized value: 0.0034942626953125
# this is the current key: 86
# This is the current key vlaue: 1078
# current keys normalized value: 0.00411224365234375
# this is the current key: 91
# This is the current key vlaue: 1352
# current keys normalized value: 0.005157470703125
# this is the current key: 95
# This is the current key vlaue: 1578
# current keys normalized value: 0.00601959228515625
# this is the current key: 97
# This is the current key vlaue: 1623
# current keys normalized value: 0.006191253662109375
# this is the current key: 99
# This is the current key vlaue: 1588
# current keys normalized value: 0.0060577392578125
# this is the current key: 103
# This is the current key vlaue: 1636
# current keys normalized value: 0.0062408447265625
# this is the current key: 106
# This is the current key vlaue: 1804
# current keys normalized value: 0.0068817138671875
# this is the current key: 125
# This is the current key vlaue: 788
# current keys normalized value: 0.0030059814453125
# this is the current key: 144
# This is the current key vlaue: 772
# current keys normalized value: 0.0029449462890625
# this is the current key: 162
# This is the current key vlaue: 1011
# current keys normalized value: 0.003856658935546875
# this is the current key: 182
# This is the current key vlaue: 2739
# current keys normalized value: 0.010448455810546875
# this is the current key: 205
# This is the current key vlaue: 2074
# current keys normalized value: 0.00791168212890625
# this is the current key: 206
# This is the current key vlaue: 1916
# current keys normalized value: 0.0073089599609375
# this is the current key: 204
# This is the current key vlaue: 2100
# current keys normalized value: 0.0080108642578125
# this is the current key: 203
# This is the current key vlaue: 2291
# current keys normalized value: 0.008739471435546875
# this is the current key: 195
# This is the current key vlaue: 2852
# current keys normalized value: 0.0108795166015625
# this is the current key: 193
# This is the current key vlaue: 3290
# current keys normalized value: 0.01255035400390625
# this is the current key: 185
# This is the current key vlaue: 3348
# current keys normalized value: 0.0127716064453125
# this is the current key: 183
# This is the current key vlaue: 2900
# current keys normalized value: 0.0110626220703125
# this is the current key: 172
# This is the current key vlaue: 1390
# current keys normalized value: 0.00530242919921875
# this is the current key: 166
# This is the current key vlaue: 1143
# current keys normalized value: 0.004360198974609375
# this is the current key: 164
# This is the current key vlaue: 1074
# current keys normalized value: 0.00409698486328125
# this is the current key: 165
# This is the current key vlaue: 1047
# current keys normalized value: 0.003993988037109375
# this is the current key: 167
# This is the current key vlaue: 1165
# current keys normalized value: 0.004444122314453125
# this is the current key: 159
# This is the current key vlaue: 986
# current keys normalized value: 0.00376129150390625
# this is the current key: 152
# This is the current key vlaue: 778
# current keys normalized value: 0.00296783447265625
# this is the current key: 136
# This is the current key vlaue: 915
# current keys normalized value: 0.003490447998046875
# this is the current key: 113
# This is the current key vlaue: 1241
# current keys normalized value: 0.004734039306640625
# this is the current key: 155
# This is the current key vlaue: 834
# current keys normalized value: 0.00318145751953125
# this is the current key: 168
# This is the current key vlaue: 1226
# current keys normalized value: 0.00467681884765625
# this is the current key: 143
# This is the current key vlaue: 731
# current keys normalized value: 0.002788543701171875
# this is the current key: 135
# This is the current key vlaue: 893
# current keys normalized value: 0.003406524658203125
# this is the current key: 128
# This is the current key vlaue: 779
# current keys normalized value: 0.002971649169921875
# this is the current key: 142
# This is the current key vlaue: 734
# current keys normalized value: 0.00279998779296875
# this is the current key: 145
# This is the current key vlaue: 795
# current keys normalized value: 0.003032684326171875
# this is the current key: 151
# This is the current key vlaue: 800
# current keys normalized value: 0.0030517578125
# this is the current key: 149
# This is the current key vlaue: 795
# current keys normalized value: 0.003032684326171875
# this is the current key: 137
# This is the current key vlaue: 818
# current keys normalized value: 0.00312042236328125
# this is the current key: 127
# This is the current key vlaue: 834
# current keys normalized value: 0.00318145751953125
# this is the current key: 122
# This is the current key vlaue: 757
# current keys normalized value: 0.002887725830078125
# this is the current key: 124
# This is the current key vlaue: 788
# current keys normalized value: 0.0030059814453125
# this is the current key: 134
# This is the current key vlaue: 943
# current keys normalized value: 0.003597259521484375
# this is the current key: 138
# This is the current key vlaue: 783
# current keys normalized value: 0.002986907958984375
# this is the current key: 157
# This is the current key vlaue: 926
# current keys normalized value: 0.00353240966796875
# this is the current key: 154
# This is the current key vlaue: 858
# current keys normalized value: 0.00327301025390625
# this is the current key: 150
# This is the current key vlaue: 776
# current keys normalized value: 0.002960205078125
# this is the current key: 163
# This is the current key vlaue: 984
# current keys normalized value: 0.003753662109375
# this is the current key: 148
# This is the current key vlaue: 821
# current keys normalized value: 0.003131866455078125
# this is the current key: 141
# This is the current key vlaue: 723
# current keys normalized value: 0.002758026123046875
# this is the current key: 177
# This is the current key vlaue: 1887
# current keys normalized value: 0.007198333740234375
# this is the current key: 176
# This is the current key vlaue: 1767
# current keys normalized value: 0.006740570068359375
# this is the current key: 189
# This is the current key vlaue: 3729
# current keys normalized value: 0.014225006103515625
# this is the current key: 52
# This is the current key vlaue: 436
# current keys normalized value: 0.0016632080078125
# this is the current key: 33
# This is the current key vlaue: 439
# current keys normalized value: 0.001674652099609375
# this is the current key: 28
# This is the current key vlaue: 745
# current keys normalized value: 0.002841949462890625
# this is the current key: 23
# This is the current key vlaue: 601
# current keys normalized value: 0.002292633056640625
# this is the current key: 20
# This is the current key vlaue: 454
# current keys normalized value: 0.00173187255859375
# this is the current key: 19
# This is the current key vlaue: 461
# current keys normalized value: 0.001758575439453125
# this is the current key: 45
# This is the current key vlaue: 409
# current keys normalized value: 0.001560211181640625
# this is the current key: 50
# This is the current key vlaue: 414
# current keys normalized value: 0.00157928466796875
# this is the current key: 39
# This is the current key vlaue: 419
# current keys normalized value: 0.001598358154296875
# this is the current key: 31
# This is the current key vlaue: 508
# current keys normalized value: 0.0019378662109375
# this is the current key: 114
# This is the current key vlaue: 1254
# current keys normalized value: 0.00478363037109375
# this is the current key: 120
# This is the current key vlaue: 844
# current keys normalized value: 0.0032196044921875
# this is the current key: 76
# This is the current key vlaue: 763
# current keys normalized value: 0.002910614013671875
# this is the current key: 66
# This is the current key vlaue: 658
# current keys normalized value: 0.00251007080078125
# this is the current key: 62
# This is the current key vlaue: 527
# current keys normalized value: 0.002010345458984375
# this is the current key: 25
# This is the current key vlaue: 770
# current keys normalized value: 0.00293731689453125
# this is the current key: 18
# This is the current key vlaue: 395
# current keys normalized value: 0.001506805419921875
# this is the current key: 17
# This is the current key vlaue: 393
# current keys normalized value: 0.001499176025390625
# this is the current key: 16
# This is the current key vlaue: 305
# current keys normalized value: 0.001163482666015625
# this is the current key: 12
# This is the current key vlaue: 197
# current keys normalized value: 0.000751495361328125
# this is the current key: 243
# This is the current key vlaue: 437
# ...
# this is the current key: 177
# This is the current key vlaue: 1235
# current keys normalized value: 0.004711151123046875
# this is the current key: 206
# This is the current key vlaue: 1914
# current keys normalized value: 0.00730133056640625
# this is the current key: 220
# This is the current key vlaue: 1201
# current keys normalized value: 0.004581451416015625
# this is the current key: 219
# This is the current key vlaue: 1287
# current keys normalized value: 0.004909515380859375
# this is the current key: 218
# This is the current key vlaue: 1317
# current keys normalized value: 0.005023956298828125
# this is the current key: 214
# This is the current key vlaue: 1198
# current keys normalized value: 0.00457000732421875
# this is the current key: 210
# This is the current key vlaue: 1469
# current keys normalized value: 0.005603790283203125
# this is the current key: 175
# This is the current key vlaue: 1086
# current keys normalized value: 0.00414276123046875
# this is the current key: 157
# This is the current key vlaue: 679
# current keys normalized value: 0.002590179443359375
# this is the current key: 160
# This is the current key vlaue: 725
# current keys normalized value: 0.002765655517578125
# this is the current key: 207
# This is the current key vlaue: 1782
# current keys normalized value: 0.00679779052734375
# this is the current key: 222
# This is the current key vlaue: 1311
# current keys normalized value: 0.005001068115234375
# this is the current key: 216
# This is the current key vlaue: 1142
# current keys normalized value: 0.00435638427734375
# this is the current key: 209
# This is the current key vlaue: 1470
# current keys normalized value: 0.00560760498046875
# this is the current key: 173
# This is the current key vlaue: 962
# current keys normalized value: 0.00366973876953125
# this is the current key: 223
# This is the current key vlaue: 1298
# current keys normalized value: 0.00495147705078125
# this is the current key: 229
# This is the current key vlaue: 640
# current keys normalized value: 0.00244140625
# this is the current key: 230
# This is the current key vlaue: 744
# current keys normalized value: 0.002838134765625
# this is the current key: 224
# This is the current key vlaue: 1153
# current keys normalized value: 0.004398345947265625
# this is the current key: 225
# This is the current key vlaue: 915
# current keys normalized value: 0.003490447998046875
# this is the current key: 215
# This is the current key vlaue: 1183
# current keys normalized value: 0.004512786865234375
# this is the current key: 168
# This is the current key vlaue: 806
# current keys normalized value: 0.00307464599609375
# this is the current key: 129
# This is the current key vlaue: 706
# current keys normalized value: 0.00269317626953125
# this is the current key: 39
# This is the current key vlaue: 492
# current keys normalized value: 0.0018768310546875
# this is the current key: 33
# This is the current key vlaue: 606
# current keys normalized value: 0.00231170654296875
# this is the current key: 34
# This is the current key vlaue: 549
# current keys normalized value: 0.002094268798828125
# this is the current key: 26
# This is the current key vlaue: 623
# current keys normalized value: 0.002376556396484375
# this is the current key: 24
# This is the current key vlaue: 520
# current keys normalized value: 0.001983642578125
# this is the current key: 47
# This is the current key vlaue: 761
# current keys normalized value: 0.002902984619140625
# this is the current key: 40
# This is the current key vlaue: 531
# current keys normalized value: 0.002025604248046875
# this is the current key: 76
# This is the current key vlaue: 865
# current keys normalized value: 0.003299713134765625
# this is the current key: 108
# This is the current key vlaue: 1447
# current keys normalized value: 0.005519866943359375
# this is the current key: 132
# This is the current key vlaue: 625
# current keys normalized value: 0.002384185791015625
# this is the current key: 140
# This is the current key vlaue: 552
# current keys normalized value: 0.002105712890625
# this is the current key: 149
# This is the current key vlaue: 574
# current keys normalized value: 0.00218963623046875
# this is the current key: 163
# This is the current key vlaue: 759
# current keys normalized value: 0.002895355224609375
# this is the current key: 167
# This is the current key vlaue: 767
# current keys normalized value: 0.002925872802734375
# this is the current key: 84
# This is the current key vlaue: 1123
# current keys normalized value: 0.004283905029296875
# this is the current key: 78
# This is the current key vlaue: 904
# current keys normalized value: 0.003448486328125
# this is the current key: 64
# This is the current key vlaue: 1037
# current keys normalized value: 0.003955841064453125
# this is the current key: 27
# This is the current key vlaue: 607
# current keys normalized value: 0.002315521240234375
# this is the current key: 19
# This is the current key vlaue: 410
# current keys normalized value: 0.00156402587890625
# this is the current key: 20
# This is the current key vlaue: 497
# current keys normalized value: 0.001895904541015625
# this is the current key: 61
# This is the current key vlaue: 1007
# current keys normalized value: 0.003841400146484375
# this is the current key: 101
# This is the current key vlaue: 1561
# current keys normalized value: 0.005954742431640625
# this is the current key: 244
# This is the current key vlaue: 395
# current keys normalized value: 0.001506805419921875
# this is the current key: 252
# This is the current key vlaue: 297
# current keys normalized value: 0.001132965087890625
# this is the current key: 250
# This is the current key vlaue: 247
# current keys normalized value: 0.000942230224609375
# this is the current key: 239
# This is the current key vlaue: 394
# current keys normalized value: 0.00150299072265625
# this is the current key: 57
# This is the current key vlaue: 845
# current keys normalized value: 0.003223419189453125
# this is the current key: 92
# This is the current key vlaue: 1281
# current keys normalized value: 0.004886627197265625
# this is the current key: 115
# This is the current key vlaue: 1239
# current keys normalized value: 0.004726409912109375
# this is the current key: 131
# This is the current key vlaue: 682
# current keys normalized value: 0.00260162353515625
# this is the current key: 164
# This is the current key vlaue: 729
# current keys normalized value: 0.002780914306640625
# this is the current key: 130
# This is the current key vlaue: 644
# current keys normalized value: 0.0024566650390625
# this is the current key: 109
# This is the current key vlaue: 1533
# current keys normalized value: 0.005847930908203125
# this is the current key: 73
# This is the current key vlaue: 849
# current keys normalized value: 0.003238677978515625
# this is the current key: 138
# This is the current key vlaue: 591
# current keys normalized value: 0.002254486083984375
# this is the current key: 139
# This is the current key vlaue: 584
# current keys normalized value: 0.002227783203125
# this is the current key: 144
# This is the current key vlaue: 581
# current keys normalized value: 0.002216339111328125
# this is the current key: 155
# This is the current key vlaue: 596
# current keys normalized value: 0.0022735595703125
# this is the current key: 122
# This is the current key vlaue: 856
# current keys normalized value: 0.003265380859375
# this is the current key: 100
# This is the current key vlaue: 1556
# current keys normalized value: 0.0059356689453125
# this is the current key: 96
# This is the current key vlaue: 1450
# current keys normalized value: 0.00553131103515625
# this is the current key: 91
# This is the current key vlaue: 1262
# current keys normalized value: 0.00481414794921875
# this is the current key: 30
# This is the current key vlaue: 810
# current keys normalized value: 0.00308990478515625
# this is the current key: 12
# This is the current key vlaue: 116
# current keys normalized value: 0.0004425048828125
# this is the current key: 32
# This is the current key vlaue: 704
# current keys normalized value: 0.002685546875
# this is the current key: 68
# This is the current key vlaue: 817
# current keys normalized value: 0.003116607666015625
# this is the current key: 95
# This is the current key vlaue: 1386
# current keys normalized value: 0.00528717041015625
# this is the current key: 114
# This is the current key vlaue: 1356
# current keys normalized value: 0.0051727294921875
# this is the current key: 165
# This is the current key vlaue: 708
# current keys normalized value: 0.0027008056640625
# this is the current key: 228
# This is the current key vlaue: 700
# current keys normalized value: 0.0026702880859375
# this is the current key: 226
# This is the current key vlaue: 762
# current keys normalized value: 0.00290679931640625
# this is the current key: 25
# This is the current key vlaue: 553
# current keys normalized value: 0.002109527587890625
# this is the current key: 22
# This is the current key vlaue: 481
# current keys normalized value: 0.001834869384765625
# this is the current key: 21
# This is the current key vlaue: 485
# current keys normalized value: 0.001850128173828125
# this is the current key: 60
# This is the current key vlaue: 885
# current keys normalized value: 0.003376007080078125
# this is the current key: 104
# This is the current key vlaue: 1524
# current keys normalized value: 0.0058135986328125
# this is the current key: 125
# This is the current key vlaue: 818
# current keys normalized value: 0.00312042236328125
# this is the current key: 128
# This is the current key vlaue: 724
# current keys normalized value: 0.0027618408203125
# this is the current key: 145
# This is the current key vlaue: 529
# current keys normalized value: 0.002017974853515625
# this is the current key: 150
# This is the current key vlaue: 525
# current keys normalized value: 0.002002716064453125
# this is the current key: 94
# This is the current key vlaue: 1382
# current keys normalized value: 0.00527191162109375
# this is the current key: 67
# This is the current key vlaue: 875
# current keys normalized value: 0.003337860107421875
# this is the current key: 38
# This is the current key vlaue: 498
# current keys normalized value: 0.00189971923828125
# this is the current key: 35
# This is the current key vlaue: 494
# current keys normalized value: 0.00188446044921875
# this is the current key: 238
# This is the current key vlaue: 399
# current keys normalized value: 0.001522064208984375
# this is the current key: 255
# This is the current key vlaue: 3182
# current keys normalized value: 0.01213836669921875
# this is the current key: 254
# This is the current key vlaue: 593
# current keys normalized value: 0.002262115478515625
# this is the current key: 106
# This is the current key vlaue: 1525
# current keys normalized value: 0.005817413330078125
# this is the current key: 170
# This is the current key vlaue: 843
# current keys normalized value: 0.003215789794921875
# this is the current key: 156
# This is the current key vlaue: 580
# current keys normalized value: 0.0022125244140625
# this is the current key: 146
# This is the current key vlaue: 516
# current keys normalized value: 0.0019683837890625
# this is the current key: 110
# This is the current key vlaue: 1497
# current keys normalized value: 0.005710601806640625
# this is the current key: 159
# This is the current key vlaue: 639
# current keys normalized value: 0.002437591552734375
# this is the current key: 124
# This is the current key vlaue: 838
# current keys normalized value: 0.00319671630859375
# this is the current key: 112
# This is the current key vlaue: 1411
# current keys normalized value: 0.005382537841796875
# this is the current key: 154
# This is the current key vlaue: 614
# current keys normalized value: 0.00234222412109375
# this is the current key: 117
# This is the current key vlaue: 1121
# current keys normalized value: 0.004276275634765625
# this is the current key: 133
# This is the current key vlaue: 615
# current keys normalized value: 0.002346038818359375
# this is the current key: 89
# This is the current key vlaue: 1214
# current keys normalized value: 0.00463104248046875
# this is the current key: 86
# This is the current key vlaue: 1080
# current keys normalized value: 0.004119873046875
# this is the current key: 232
# This is the current key vlaue: 670
# current keys normalized value: 0.00255584716796875
# this is the current key: 127
# This is the current key vlaue: 740
# current keys normalized value: 0.0028228759765625
# this is the current key: 116
# This is the current key vlaue: 1262
# current keys normalized value: 0.00481414794921875
# this is the current key: 119
# This is the current key vlaue: 1090
# current keys normalized value: 0.00415802001953125
# this is the current key: 99
# This is the current key vlaue: 1495
# current keys normalized value: 0.005702972412109375
# this is the current key: 134
# This is the current key vlaue: 612
# current keys normalized value: 0.0023345947265625
# this is the current key: 247
# This is the current key vlaue: 307
# current keys normalized value: 0.001171112060546875
# this is the current key: 243
# This is the current key vlaue: 408
# current keys normalized value: 0.001556396484375
# this is the current key: 236
# This is the current key vlaue: 456
# current keys normalized value: 0.001739501953125
# this is the current key: 111
# This is the current key vlaue: 1439
# current keys normalized value: 0.005489349365234375
# this is the current key: 113
# This is the current key vlaue: 1357
# current keys normalized value: 0.005176544189453125
# this is the current key: 251
# This is the current key vlaue: 236
# current keys normalized value: 0.0009002685546875
# this is the current key: 107
# This is the current key vlaue: 1550
# current keys normalized value: 0.00591278076171875
# this is the current key: 248
# This is the current key vlaue: 321
# current keys normalized value: 0.001224517822265625
# this is the current key: 17
# This is the current key vlaue: 324
# current keys normalized value: 0.0012359619140625
# this is the current key: 253
# This is the current key vlaue: 431
# current keys normalized value: 0.001644134521484375
# this is the current key: 237
# This is the current key vlaue: 441
# current keys normalized value: 0.001682281494140625
# this is the current key: 234
# This is the current key vlaue: 526
# current keys normalized value: 0.00200653076171875
# this is the current key: 11
# This is the current key vlaue: 115
# current keys normalized value: 0.000438690185546875
# this is the current key: 249
# This is the current key vlaue: 280
# current keys normalized value: 0.001068115234375
# this is the current key: 13
# This is the current key vlaue: 138
# current keys normalized value: 0.00052642822265625
# this is the current key: 15
# This is the current key vlaue: 214
# current keys normalized value: 0.00081634521484375
# this is the current key: 246
# This is the current key vlaue: 376
# current keys normalized value: 0.001434326171875
# this is the current key: 233
# This is the current key vlaue: 575
# current keys normalized value: 0.002193450927734375
# this is the current key: 240
# This is the current key vlaue: 422
# current keys normalized value: 0.00160980224609375
# this is the current key: 7
# This is the current key vlaue: 113
# current keys normalized value: 0.000431060791015625
# this is the current key: 10
# This is the current key vlaue: 98
# current keys normalized value: 0.00037384033203125
# this is the current key: 8
# This is the current key vlaue: 97
# current keys normalized value: 0.000370025634765625
# this is the current key: 9
# This is the current key vlaue: 99
# current keys normalized value: 0.000377655029296875
# this is the current key: 3
# This is the current key vlaue: 296
# current keys normalized value: 0.001129150390625
# this is the current key: 4
# This is the current key vlaue: 209
# current keys normalized value: 0.000797271728515625
# this is the current key: 0
# This is the current key vlaue: 803
# current keys normalized value: 0.003063201904296875
# this is the current key: 5
# This is the current key vlaue: 164
# current keys normalized value: 0.0006256103515625
# this is the current key: 1
# This is the current key vlaue: 498
# current keys normalized value: 0.00189971923828125
# this is the current key: 6
# This is the current key vlaue: 117
# current keys normalized value: 0.000446319580078125
# this is the current key: 2
# This is the current key vlaue: 428
# current keys normalized value: 0.0016326904296875

# %%
#######################################################################
#this section will have comments for each picture to avoid picture overlap

import matplotlib.pyplot as plot

#plot.bar(red_normal.keys(), red_normal.values(),1.5, color = 'r')
#plot.savefig('red_normal_hard.png')

plot.bar(green_normal.keys(), green_normal.values(),1.5, color = 'g')
plot.savefig('green_normal_hard.png')

#plot.bar(blue_normal.keys(), blue_normal.values(),1.5, color = 'b')
#plot.savefig('blue_normal_hard.png')
